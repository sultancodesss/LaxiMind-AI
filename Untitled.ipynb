# %%
import pandas as pd

# %%
# Series : 1 dimension
# DataFrame : 2 Dimension

# %%
df = pd.read_csv("C:/Users/mdsul/Downloads/hr.csv")

# %%
df
# Out:
#      Category                                       Product Name  \
# 0      clocks           Multicolour Metal Sun Novelty Wall Clock
# 1      clocks  Gold Aluminium Analog Designer Pendulum Pendul...
# 2      clocks                   Decorative Black Iron Wall Clock
# 3      clocks                   Decorative Black Iron Wall Clock
# 4      clocks                         Yellow Metal Railway Clock
# ...       ...                                                ...
# 2678   clocks                               Track Art Wall Clock
# 2679   clocks               Geometric Pattern Diamond Wall Clock
# 2680   clocks              Duomo Italian Architecture Wall Clock
# 2681   clocks         Lollologio White Veneer Novelty Wall Clock
# 2682   clocks  Natural Wood Mango Wood & Metal Novelty Wall C...
#
#                 Brand      MRP  Selling Price Discount  \
# 0        Malik Design   3999.0         2849.0       29
# 1     De Maison Decor   7800.0         5460.0       30
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2683 entries, 0 to 2682
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       2683 non-null   object
#  1   Product Name   2682 non-null   object
#  2   Brand          2662 non-null   object
#  3   MRP            2662 non-null   float64
#  4   Selling Price  2662 non-null   float64
#  5   Discount       2662 non-null   object
#  6   Link           2642 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 146.9+ KB

# %%
df['Category'].unique()
# Out:
# array(['clocks', 'Decorative Multicolour Wood & Mdf Wall Clock',
#        'Plastic Wall Clock', 'Brown Wood & Mdf Wall Clock', 'Bike',
#        'Multicolour Iron Table Clock', 'Wood & Mdf Wall Clock',
#        'Multicolour Wood & Mdf Wall Clock', 'Clock'], dtype=object)

# %%
df['Product Name'].unique()
# Out:
# array(['Multicolour Metal Sun Novelty Wall Clock',
#        'Gold Aluminium Analog Designer Pendulum Pendulum Wall Clock',
#        'Decorative Black Iron Wall Clock', ...,
#        'Duomo Italian Architecture Wall Clock',
#        'Lollologio White Veneer Novelty Wall Clock',
#        'Natural Wood Mango Wood & Metal Novelty Wall Clock'],
#       shape=(1626,), dtype=object)

# %%
df['Discount'].unique()
# Out:
# array(['29', '30', '24', '43', '44', '41', '0', '28', '26', '46', '10',
#        '27', '25', '42', '47', '68', '33', '31', '70', '53', '56', '32',
#        '65', '50', nan,
#        'https://www.pepperfry.com/product/moderndecorative-multicolour-wood-mdf-wall-clock-2175185.html',
#        '66', '60', '20', '35', '34', '59', '54', '63', '61', '58', '55',
#        '17', '36', '49', '23', '40', '52',
#        'https://www.pepperfry.com/product/vintage-distress-multicolourplastic-wall-clock-2175101.html',
#        'https://www.pepperfry.com/product/floral-shapebrown-wood-mdf-wall-clock-2175169.html',
#        'https://www.pepperfry.com/product/3d-bubble-shape-multicolourplastic-wall-clock-2175135.html',
#        '57', '38', '67', '21', '83', '37', '39',
#        'https://www.pepperfry.com/product/heart-with-love-multicolourplastic-wall-clock-2175141.html',
#        '48',
#        'https://www.pepperfry.com/product/decorative-bike-multicolour-iron-table-clock-by-decorum-2147363.html',
# ...

# %%
df.describe() # numerical columns - statistics
# Out:
#                 MRP  Selling Price
# count   2662.000000    2662.000000
# mean    3391.985725    1871.960180
# std     4149.566928    2550.015112
# min      399.000000      26.000000
# 25%     1499.000000     799.000000
# 50%     2199.000000    1199.000000
# 75%     4299.000000    2149.000000
# max    82099.000000   53889.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Category          0
# Product Name      1
# Brand            21
# MRP              21
# Selling Price    21
# Discount         21
# Link             41
# dtype: int64

# %%
df['MRP'].fillna(df['MRP'].median(), inplace = True)

# %%
df['Selling Price'].fillna(df['Selling Price'].median(), inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2642 entries, 0 to 2682
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Category       2642 non-null   object
#  1   Product Name   2642 non-null   object
#  2   Brand          2642 non-null   object
#  3   MRP            2642 non-null   float64
#  4   Selling Price  2642 non-null   float64
#  5   Discount       2642 non-null   object
#  6   Link           2642 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 165.1+ KB

# %%
df.drop('Discount',axis = 'columns', inplace = True)

# %%
df.head()
# Out:
#   Category                                       Product Name  \
# 0   clocks           Multicolour Metal Sun Novelty Wall Clock
# 1   clocks  Gold Aluminium Analog Designer Pendulum Pendul...
# 2   clocks                   Decorative Black Iron Wall Clock
# 3   clocks                   Decorative Black Iron Wall Clock
# 4   clocks                         Yellow Metal Railway Clock
#
#              Brand     MRP  Selling Price  \
# 0     Malik Design  3999.0         2849.0
# 1  De Maison Decor  7800.0         5460.0
# 2     Mint Furnish  2499.0         1899.0
# 3     Mint Furnish  2499.0         1899.0
# 4       Craft Tree  4119.0         2899.0
#
#                                                 Link
# 0  https://www.pepperfry.com/product/multicolour-...
# 1  https://www.pepperfry.com/product/noir-pendulu...
# 2  https://www.pepperfry.com/product/decorative-b...
# 3  https://www.pepperfry.com/product/decorative-b...
# 4  https://www.pepperfry.com/product/yellow-metal...
